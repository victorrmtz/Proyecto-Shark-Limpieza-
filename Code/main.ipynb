# %% [markdown]
# # PROYECTO LIMPIEZA SHARKS

# %%
#Importamos las librerias necesarias.
import pandas as pd 
import numpy as np
import datetime
import re
import funciones as fn

import warnings
warnings.filterwarnings('ignore')  #Quitar prints de warnings

pd.set_option('display.max_columns', None) #Imprimir todas las columnas

# %%
data_ori = pd.read_csv('../Data/attacks.csv', encoding='latin1') #Cargamos el archivo

# %%
data_ori.head() #Visualizamos la cabeza del csv
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
data = data_ori.copy() #Creamos una copia para trabajar sobra ella
data.shape #Longitudes del dataframe
# Out:
# (25723, 24)

# %%
data.columns #nombre de las columnas
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
data.info(memory_usage='deep') #informacion del dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
data.drop_duplicates(inplace=True) #Eliminamos los duplicados
data.shape
# Out:
# (6312, 24)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Case Number                  2
# Date                        10
# Year                        12
# Type                        14
# Country                     60
# Area                       465
# Location                   550
# Activity                   554
# Name                       220
# Sex                        575
# Age                       2841
# Injury                      38
# Fatal (Y/N)                549
# Time                      3364
# Species                   2848
# Investigator or Source      27
# pdf                         10
# href formula                11
# href                        10
# Case Number.1               10
# Case Number.2               10
# original order               3
# Unnamed: 22               6311
# Unnamed: 23               6310
# dtype: int64

# %%
nan_cols_pr=data.isna().mean() * 100 #porcentaje de nulos por columna

nan_cols_pr[nan_cols>0]
# Out:
# Case Number                0.031686
# Date                       0.158428
# Year                       0.190114
# Type                       0.221800
# Country                    0.950570
# Area                       7.366920
# Location                   8.713561
# Activity                   8.776933
# Name                       3.485425
# Sex                        9.109632
# Age                       45.009506
# Injury                     0.602028
# Fatal (Y/N)                8.697719
# Time                      53.295311
# Species                   45.120406
# Investigator or Source     0.427757
# pdf                        0.158428
# href formula               0.174271
# href                       0.158428
# Case Number.1              0.158428
# Case Number.2              0.158428
# original order             0.047529
# Unnamed: 22               99.984157
# Unnamed: 23               99.968314
# dtype: float64

# %%
data.drop(columns=nan_cols_pr[nan_cols_pr>80].index, inplace=True)

# %%
#Comprobamos los porcentajes de nulos de la columna
nan_cols_pr=data.isna().mean() * 100

nan_cols_pr[nan_cols>0]
# Out:
# Case Number                0.031686
# Date                       0.158428
# Year                       0.190114
# Type                       0.221800
# Country                    0.950570
# Area                       7.366920
# Location                   8.713561
# Activity                   8.776933
# Name                       3.485425
# Sex                        9.109632
# Age                       45.009506
# Injury                     0.602028
# Fatal (Y/N)                8.697719
# Time                      53.295311
# Species                   45.120406
# Investigator or Source     0.427757
# pdf                        0.158428
# href formula               0.174271
# href                       0.158428
# Case Number.1              0.158428
# Case Number.2              0.158428
# original order             0.047529
# dtype: float64

# %%
data.tail() #Vemos que hay filas enteras de nulos(Por tanto repetidas)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6307            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6308            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6309            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8702          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        Age Injury Fatal (Y/N) Time Species  Investigator or Source  pdf  \
# 6307   NaN    NaN         NaN  NaN      NaN                    NaN  NaN
# 6308   NaN    NaN         NaN  NaN      NaN                    NaN  NaN
# 6309   NaN    NaN         NaN  NaN      NaN                    NaN  NaN
# 8702   NaN    NaN         NaN  NaN      NaN                    NaN  NaN
# 25722  NaN    NaN         NaN  NaN      NaN                    NaN  NaN
#
#       href formula href Case Number.1 Case Number.2  original order
# ...

# %%
data.drop_duplicates().shape == data.shape #Vemos que es correcto que hay repetidas
# Out:
# True

# %%
data[data['Case Number'].isna()]
# Out:
#      Case Number                  Date    Year      Type Country     Area  \
# 5488         NaN  Reported 06-Sep-1905  1905.0  Provoked     USA  Florida
# 8702         NaN                   NaN     NaN       NaN     NaN      NaN
#
#                           Location Activity         Name Sex   Age  \
# 5488  Fort Pierce, St Lucie County  Fishing  David Curry    M  NaN
# 8702                           NaN      NaN          NaN  NaN  NaN
#
#                                                  Injury Fatal (Y/N) Time  \
# 5488  Lacerations to leg from hooked shark PROVOKED ...           N  NaN
# 8702                                                NaN         NaN  NaN
#
#      Species           Investigator or Source                     pdf  \
# 5488      NaN  Muncie Evening Press, 8/6/1913  1905.09.06.R-Curry.pdf
# 8702      NaN                             NaN                     NaN
#
#                                            href formula  \
# ...

# %%
data = data.dropna(how='all') #Borramos las filas donde todos los valores sean nulos

# %%
data.shape
# Out:
# (6311, 22)

# %%
data[data['Case Number'].isna()] #Valor nulo de la columna seleccionada
# Out:
#      Case Number                  Date    Year      Type Country     Area  \
# 5488         NaN  Reported 06-Sep-1905  1905.0  Provoked     USA  Florida
#
#                           Location Activity         Name Sex   Age  \
# 5488  Fort Pierce, St Lucie County  Fishing  David Curry    M  NaN
#
#                                                  Injury Fatal (Y/N) Time  \
# 5488  Lacerations to leg from hooked shark PROVOKED ...           N  NaN
#
#      Species           Investigator or Source                     pdf  \
# 5488      NaN  Muncie Evening Press, 8/6/1913  1905.09.06.R-Curry.pdf
#
#                                            href formula  \
# 5488  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 5488  http://sharkattackfile.net/spreadsheets/pdf_di...  1905.09.06.R
#
#      Case Number.2  original order
# 5488  1905.09.06.R           815.0

# %%
data.head() #Nos fijamos en el df que las dos primeras columnas nos dicen lo mismo
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
f_c = data[data['Case Number'].isna()].index #cogemos index de la fila que nos interesa
f_c
# Out:
# Int64Index([5488], dtype='int64')

# %%
d = data.at[f_c[0],'Date'] #Cogemos el dato que queremos guardar
d
# Out:
# 'Reported 06-Sep-1905'

# %%
x = re.findall('\d+[-\dA-Za-z-]+', d)[0]
x
# Out:
# '06-Sep-1905'

# %%
x = x.replace('Sep', '09')

# %%
fecha_dt = datetime.datetime.strptime(x, '%d-%m-%Y')
fecha_dt = str(fecha_dt)[0:10].replace('-','.')
fecha_dt
# Out:
# '1905.09.06'

# %%
data['Case Number'].fillna(fecha_dt, inplace=True) #Cambiamos el valor de la columna

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Date                         9
# Year                        11
# Type                        13
# Country                     59
# Area                       464
# Location                   549
# Activity                   553
# Name                       219
# Sex                        574
# Age                       2840
# Injury                      37
# Fatal (Y/N)                548
# Time                      3363
# Species                   2847
# Investigator or Source      26
# pdf                          9
# href formula                10
# href                         9
# Case Number.1                9
# Case Number.2                9
# original order               2
# dtype: int64

# %%
data[data['Date'].isna()] #Los datos que nos muestra de las columnas no nos interesa
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6302            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6303            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6304            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6305            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6306            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6307            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6308            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6309            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        Age Injury Fatal (Y/N) Time Species  Investigator or Source  pdf  \
# 6302   NaN    NaN         NaN  NaN      NaN                    NaN  NaN
# 6303   NaN    NaN         NaN  NaN      NaN                    NaN  NaN
# ...

# %%
lst_index = data[data['Date'].isna()].index
lst_index
# Out:
# Int64Index([6302, 6303, 6304, 6305, 6306, 6307, 6308, 6309, 25722], dtype='int64')

# %%
data.drop(index=lst_index, inplace=True) #Borramos las filas por los indices

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Year                         2
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
data[data['Year'].isna()]
# Out:
#        Case Number                  Date  Year        Type    Country  \
# 187   2017.01.08.R  Reported 08-Jan-2017   NaN     Invalid  AUSTRALIA
# 6079  1836.08.19.R  Reported 19-Aug-1836   NaN  Unprovoked    ENGLAND
#
#             Area    Location      Activity          Name Sex   Age  \
# 187   Queensland         NaN  Spearfishing  Kerry Daniel    M   35
# 6079  Cumberland  Whitehaven      Swimming         a boy    M  NaN
#
#                                       Injury Fatal (Y/N) Time    Species   \
# 187   No attack, shark made a threat display         NaN  NaN  Bull shark
# 6079                                   FATAL           Y  NaN         NaN
#
#       Investigator or Source                           pdf  \
# 187   Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf
# 6079          C. Moore, GSAF   1835.08.19.R-Whitehaven.pdf
#
#                                            href formula  \
# 187   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
data['Case Number'].head() #Visualizo la columna que voy ha utilizar
# Out:
# 0    2018.06.25
# 1    2018.06.18
# 2    2018.06.09
# 3    2018.06.08
# 4    2018.06.04
# Name: Case Number, dtype: object

# %%
type(data['Case Number'][0]) #es str
# Out:
# str

# %%
data.shape
# Out:
# (6302, 22)

# %%
x = [2017.0, 1836.0]
x
# Out:
# [2017.0, 1836.0]

# %%
mal_index = []
mal_index =data[data['Year'].isna()].index

# %%
data.loc[mal_index, 'Year']=x

# %%
data[data['Year'].isna()]
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order]
# Index: []

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
#data.drop('hola', axis=1)

# %%
data.tail()
# Out:
#      Case Number         Date  Year        Type             Country  \
# 6297     ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age  \
# 6297                   male    M  NaN
# ...

# %%
data[data['Type'].isna()]
# Out:
#        Case Number                  Date    Year Type    Country  \
# 85    2017.09.15.a           15-Sep-2017  2017.0  NaN      SAMOA
# 382     2015.07.27           27-Jul-2015  2015.0  NaN  AUSTRALIA
# 4867  1936.09.11.R  Reported 11-Sep-1936  1936.0  NaN    VIETNAM
# 5705  1890.03.03.R  Reported 03-Mar-1890  1890.0  NaN     CEYLON
#
#                Area          Location           Activity           Name Sex   \
# 85     Upolu Island         Nofoalii            Fishing           male    M
# 382        Victoria  Tyrendarra Beach            Surfing           male    M
# 4867            NaN            Saigon  Wreck of a sampam         8 crew    M
# 5705            NaN               NaN             Diving  a pearl diver    M
#
#       Age                      Injury Fatal (Y/N)   Time Species   \
# 85    NaN  Injuries to hands and legs           N  Night      NaN
# 382    40              Injury to hand         NaN    NaN      NaN
# ...

# %%
data['Type'].unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat', 'Boatomg'], dtype=object)

# %%
data.Type.fillna('Unknown', inplace=True)

# %%
data['Type'].unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', 'Unknown', 'Boat', 'Boatomg'], dtype=object)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
data[data['Country'].isna()]
# Out:
#          Case Number                  Date    Year          Type Country  \
# 62      2017.11.13.R  Reported 13-Nov-2017  2017.0    Unprovoked     NaN
# 525       2014.08.00              Aug-2014  2014.0       Invalid     NaN
# 2956    1983.00.00.d              Ca. 1983  1983.0    Unprovoked     NaN
# 3378      1970.11.00              Nov-1970  1970.0    Unprovoked     NaN
# 3387      1970.08.02           02-Aug-1970  1970.0       Invalid     NaN
# 3388      1970.07.05            5-Jul-1970  1970.0    Unprovoked     NaN
# 3395    1970.04.00.b              Apr-1970  1970.0      Provoked     NaN
# 3399      1970.02.05            5-Feb-1970  1970.0    Unprovoked     NaN
# 3425      1969.08.00              Aug-1969  1969.0    Unprovoked     NaN
# 3605      1965.10.21           21-Oct-1965  1965.0    Unprovoked     NaN
# 3661      1964.09.27           27-Sep-1964  1964.0       Invalid     NaN
# 4018      1960.01.26           26-Jan-1960  1960.0  Sea Disaster     NaN
# ...

# %%
data.Country.fillna('Unknown', inplace=True)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
data[data['Area'].isna()].head()
# Out:
#      Case Number                  Date    Year          Type        Country  \
# 32    2018.04.09           09-Apr-2018  2018.0    Unprovoked  NEW CALEDONIA
# 33    2018.04.05           05-Apr-2018  2018.0    Unprovoked        BAHAMAS
# 48    2018.01.21           21-Jan-2018  2018.0    Unprovoked  NEW CALEDONIA
# 56    2017.12.09           09-Dec-2017  2017.0    Unprovoked        BAHAMAS
# 59  2017.11.25.R  Reported 25-Nov-2017  2017.0  Sea Disaster          LIBYA
#
#    Area               Location          Activity                 Name Sex   \
# 32  NaN  Magenta Beach, Noumea       Windsurfing                  NaN  NaN
# 33  NaN                 Bimini          Swimming      Shane McConnell    M
# 48  NaN               Nouville      Spearfishing                 male    M
# 56  NaN                    NaN        Snorkeling  Sarah Illig-Carroll    F
# 59  NaN         Gars Garabulli  2 boats capsized          31 migrants  NaN
#
# ...

# %%
data.Area.fillna('Unknown', inplace=True)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
data[data['Location'].isna()].head()
# Out:
#       Case Number                  Date    Year        Type  Country  \
# 56     2017.12.09           09-Dec-2017  2017.0  Unprovoked  BAHAMAS
# 62   2017.11.13.R  Reported 13-Nov-2017  2017.0  Unprovoked  Unknown
# 101    2017.08.18           18-Aug-2017  2017.0  Unprovoked  BAHAMAS
# 110  2017.07.26.R  Reported 26-Jul-2017  2017.0  Unprovoked  BAHAMAS
# 132  2017.06.14.R  Reported 14-Jun-2017  2017.0  Unprovoked  BAHAMAS
#
#                                  Area Location        Activity  \
# 56                            Unknown      NaN      Snorkeling
# 62                            Unknown      NaN         Surfing
# 101                           Unknown      NaN    Spearfishing
# 110  40 miles off Grand Bahama Island      NaN    Spearfishing
# 132                           Unknown      NaN  Feeding sharks
#
#                     Name Sex   Age                           Injury  \
# 56   Sarah Illig-Carroll    F   25              Minor injury to arm
# ...

# %%
data.Location.fillna('Unknown', inplace=True)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
data[data['Activity'].isna()].head()
# Out:
#       Case Number         Date    Year        Type    Country  \
# 47     2018.01.28  28-Jan-2018  2018.0  Unprovoked  AUSTRALIA
# 108  2017.07.29.a  29-Jul-2017  2017.0  Unprovoked        USA
# 112  2017.07.23.b  23-Jul-2017  2017.0  Unprovoked        USA
# 114    2017.07.22  22-Jul-2017  2017.0  Unprovoked        USA
# 154  2017.04.17.b  17-Apr-2017  2017.0  Unprovoked        USA
#
#                   Area                             Location Activity  \
# 47   Western Australia                             Cone Bay      NaN
# 108     South Carolina  DeBordieu Colony, Georgetown County      NaN
# 112         New Jersey                              Ventnor      NaN
# 114            Florida          Snipes Point, Monroe County      NaN
# 154            Florida        Daytona Beach, Volusia County      NaN
#
#                Name Sex   Age                             Injury Fatal (Y/N)  \
# 47             male    M   18              Injuries to right leg           N
# ...

# %%
data.Activity.fillna('Unknown', inplace=True)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
data[data['Name'].isna()].head()
# Out:
#       Case Number         Date    Year        Type        Country  \
# 32     2018.04.09  09-Apr-2018  2018.0  Unprovoked  NEW CALEDONIA
# 86     2017.09.14     Sep-2017  2017.0     Boating      AUSTRALIA
# 124    2017.07.02  02-Jul-2017  2017.0     Invalid        COMOROS
# 154  2017.04.17.b  17-Apr-2017  2017.0  Unprovoked            USA
# 184  2017.01.13.b  13-Jan-2017  2017.0  Unprovoked      AUSTRALIA
#
#                   Area                       Location     Activity Name Sex   \
# 32             Unknown          Magenta Beach, Noumea  Windsurfing  NaN  NaN
# 86   Westerm Australia                      Esperance      Fishing  NaN  NaN
# 124            Anjouan                           Moya      Fishing  NaN  NaN
# 154            Florida  Daytona Beach, Volusia County      Unknown  NaN  NaN
# 184         Queensland                      Clairview     Swimming  NaN    M
#
#      Age                                             Injury Fatal (Y/N)  \
# ...

# %%
data.Name.fillna('Unknown', inplace=True)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
data[data['Sex '].isna()].head()
# Out:
#       Case Number                  Date    Year          Type        Country  \
# 32     2018.04.09           09-Apr-2018  2018.0    Unprovoked  NEW CALEDONIA
# 59   2017.11.25.R  Reported 25-Nov-2017  2017.0  Sea Disaster          LIBYA
# 86     2017.09.14              Sep-2017  2017.0       Boating      AUSTRALIA
# 124    2017.07.02           02-Jul-2017  2017.0       Invalid        COMOROS
# 154  2017.04.17.b           17-Apr-2017  2017.0    Unprovoked            USA
#
#                   Area                       Location          Activity  \
# 32             Unknown          Magenta Beach, Noumea       Windsurfing
# 59             Unknown                 Gars Garabulli  2 boats capsized
# 86   Westerm Australia                      Esperance           Fishing
# 124            Anjouan                           Moya           Fishing
# 154            Florida  Daytona Beach, Volusia County           Unknown
#
# ...

# %%
data['Sex '].fillna('Unknown', inplace=True)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
data[data['Age'].isna()].head()
# Out:
#      Case Number         Date    Year          Type       Country  \
# 3     2018.06.08  08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0      Provoked        MEXICO
# 5   2018.06.03.b  03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 15    2018.05.12  12-May-2018  2018.0    Unprovoked  SOUTH AFRICA
# 16    2018.05.09  09-May-2018  2018.0  Questionable     AUSTRALIA
#
#                      Area                   Location      Activity  \
# 3         New South Wales         Arrawarra Headland       Surfing
# 4                  Colima                   La Ticla   Free diving
# 5         New South Wales         Flat Rock, Ballina  Kite surfing
# 15  Eastern Cape Province  Nahoon Beach, East London       Surfing
# 16        New South Wales     Sharpes Beach, Ballina       Surfing
#
#               Name Sex   Age  \
# 3             male    M  NaN
# 4   Gustavo Ramos     M  NaN
# 5          Chris
#     M  NaN
# 15            male    M  NaN
# ...

# %%
data['Age'].fillna('Unknown', inplace=True)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
data[data['Injury'].isna()].head()
# Out:
#        Case Number         Date    Year        Type    Country  \
# 1270  2008.04.20.a  20-Apr-2008  2008.0  Unprovoked  AUSTRALIA
# 1366    2007.07.00     Jul-2007  2007.0     Invalid    SENEGAL
# 2250    1997.06.07  07-Jun-1997  1997.0  Unprovoked     BRAZIL
# 2267    1996.12.29  29-Dec-1996  1996.0  Unprovoked  AUSTRALIA
# 2648    1990.00.00         1990  1990.0  Unprovoked        USA
#
#                  Area                    Location Activity               Name  \
# 1270  New South Wales               Crescent Head  Unknown    Jamie Adlington
# 1366          Unknown                     Unknown   Murder         Alex Takyi
# 2250   Rio de Janeiro  Copacabana, Rio de Janeiro  Bathing  José Luiz Lipiani
# 2267       Queensland                Coolum Beach  Surfing         Blair Hall
# 2648          Florida  Pensacola, Escambia County  Surfing               male
#
#          Sex       Age Injury Fatal (Y/N)   Time               Species   \
# ...

# %%
data['Injury'].fillna('Unknown', inplace=True)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
data['Fatal (Y/N)'].unique()
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %%
data['Fatal (Y/N)'].fillna('Unknown', inplace=True)

# %%
data['Fatal (Y/N)'].unique()
# Out:
# array(['N', 'Y', 'Unknown', 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %%
data['Fatal (Y/N)'].value_counts()
# Out:
# N          4293
# Y          1388
# Unknown     539
# UNKNOWN      71
#  N            7
# M             1
# 2017          1
# N             1
# y             1
# Name: Fatal (Y/N), dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6302 entries, 0 to 6301
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6302 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6302 non-null   float64
#  3   Type                    6302 non-null   object
#  4   Country                 6302 non-null   object
#  5   Area                    6302 non-null   object
#  6   Location                6302 non-null   object
#  7   Activity                6302 non-null   object
#  8   Name                    6302 non-null   object
#  9   Sex                     6302 non-null   object
#  10  Age                     6302 non-null   object
#  11  Injury                  6302 non-null   object
#  12  Fatal (Y/N)             6302 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
data['Fatal (Y/N)'].replace(['UNKNOWN', ' N', 'N ', 'y', '2017','M'],
                           ['Unknown', 'N', 'N', 'Y', 'Unknown', 'Unknown'],
                           inplace=True)

# %%
data['Fatal (Y/N)'].unique()
# Out:
# array(['N', 'Y', 'Unknown'], dtype=object)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
data[data['Time'].isna()].head()
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5   2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 7     2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 11    2018.05.21  21-May-2018  2018.0  Unprovoked        USA   South Carolina
#
#                                              Location         Activity  \
# 3                                  Arrawarra Headland          Surfing
# 4                                            La Ticla      Free diving
# 5                                  Flat Rock, Ballina     Kite surfing
# 7   Lighhouse Point Park, Ponce Inlet, Volusia County          Fishing
# 11                  Isle of Palms,  Charleston County  Boogie boarding
#
#               Name Sex       Age  \
# ...

# %%
data['Time'].fillna('Unknown', inplace=True)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Species                   2838
# Investigator or Source      17
# href formula                 1
# dtype: int64

# %%
data[data['Species '].isna()].head()
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 5   2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 9   2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
# 11    2018.05.21  21-May-2018  2018.0  Unprovoked        USA   South Carolina
#
#                              Location         Activity             Name Sex   \
# 1      St. Simon Island, Glynn County         Standing  Adyson McNeely     F
# 2                        Habush, Oahu          Surfing      John Denges    M
# 5                  Flat Rock, Ballina     Kite surfing          Chris
#     M
# 9       Daytona Beach, Volusia County         Standing             male    M
# 11  Isle of Palms,  Charleston County  Boogie boarding     Trey de Boer    M
#
# ...

# %%
data['Species '].fillna('Unknown', inplace=True)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Investigator or Source    17
# href formula               1
# dtype: int64

# %%
data[data['Investigator or Source'].isna()]
# Out:
#         Case Number                  Date    Year        Type       Country  \
# 119    2017.07.14.a           14-Jul-2017  2017.0  Unprovoked     AUSTRALIA
# 290    2016.04.07.b           07-Apr-2016  2016.0  Unprovoked           USA
# 382      2015.07.27           27-Jul-2015  2015.0     Unknown     AUSTRALIA
# 631    2013.08.31.b           31-Aug-2013  2013.0  Unprovoked       BAHAMAS
# 1130     2009.04.28           28-Apr-2009  2009.0  Unprovoked           USA
# 1242   2008.06.28.a           28-Jun-2008  2008.0  Unprovoked  SOUTH AFRICA
# 2125     1999.04.22           22-Apr-1999  1999.0  Unprovoked     MAURITIUS
# 2144   1999.00.00.a                  1999  1999.0     Invalid           USA
# 2460   1994.00.00.a                  1994  1994.0  Unprovoked           USA
# 2648     1990.00.00                  1990  1990.0  Unprovoked           USA
# 3508   1967.09.07.a           07-Sep-1967  1967.0  Unprovoked           USA
# ...

# %%
data['Investigator or Source'].unique()
# Out:
# array(['R. Collier, GSAF', 'K.McMurray, TrackingSharks.com',
#        'B. Myatt, GSAF', ..., 'F. Schwartz, p.23; C. Creswell, GSAF',
#        'The Sun, 10/20/1938', 'S.W. Baker'], dtype=object)

# %%
data['Investigator or Source'].fillna('Unknown', inplace=True)

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# href formula    1
# dtype: int64

# %%
data[data['href formula'].isna()]
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 3244  1975.01.19  19-Jan-1975  1975.0  Unprovoked  AUSTRALIA  South Australia
#
#         Location Activity             Name Sex  Age  \
# 3244  Coffin Bay  Surfing  David Barrowman    M  17
#
#                          Injury Fatal (Y/N)     Time Species   \
# 3244  FATAL, body not recovered           Y  Unknown  Unknown
#
#                                  Investigator or Source  \
# 3244  J. West; Adelaide Advertiser, 1/20/1975; P. Ke...
#
#                            pdf href formula  \
# 3244  1975.01.19-Barrowman.pdf          NaN
#
#                                                    href Case Number.1  \
# 3244  http://sharkattackfile.net/spreadsheets/pdf_di...    1975.01.19
#
#      Case Number.2  original order
# 3244    1975.01.19          3059.0

# %%
ind = data[data['href formula'].isna()].index

# %%
valor = data[data['href formula'].isna()].href.values

# %%
data.href.head()
# Out:
# 0    http://sharkattackfile.net/spreadsheets/pdf_di...
# 1    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2    http://sharkattackfile.net/spreadsheets/pdf_di...
# 3    http://sharkattackfile.net/spreadsheets/pdf_di...
# 4    http://sharkattackfile.net/spreadsheets/pdf_di...
# Name: href, dtype: object

# %%
data.loc[ind, 'href formula'] = valor

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Series([], dtype: int64)

# %%
data.drop_duplicates().shape==data.shape
# Out:
# True

# %% [markdown]
# ## Valores incorrectos

# %%
data.columns = ['Case_Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
       'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal(Y/N)', 'Time',
       'Species', 'Investigator_or_Source', 'Pdf', 'Href_Formula', 'Href',
       'Case_Number.1', 'Case_Number.2', 'Original_Order']

# %%
data.columns
# Out:
# Index(['Case_Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal(Y/N)', 'Time',
#        'Species', 'Investigator_or_Source', 'Pdf', 'Href_Formula', 'Href',
#        'Case_Number.1', 'Case_Number.2', 'Original_Order'],
#       dtype='object')

# %%
data.Country.unique() #Esta Correcta
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA',
#        'ECUADOR', 'MALAYSIA', 'LIBYA', 'Unknown', 'CUBA', 'MAURITIUS',
#        'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
#        'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS',
#        'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'FIJI', 'PUERTO RICO',
#        'ITALY', 'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES',
#        'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA',
# ...

# %%
data['Fatal(Y/N)'].unique() #Esta Correcta
# Out:
# array(['N', 'Y', 'Unknown'], dtype=object)

# %%
data.Year.unique()
# Out:
# array([2018., 2017., 2016., 2015., 2014., 2013., 2012., 2011., 2010.,
#        2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#        2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994., 1993.,
#        1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986., 1985.,
#        1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976., 1975.,
#        1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966., 1965.,
#        1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957., 1956.,
#        1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948., 1848.,
#        1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940., 1939.,
#        1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931., 1930.,
#        1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922., 1921.,
#        1920., 1919., 1918., 1917., 1916., 1915., 1914., 1913., 1912.,
#        1911., 1910., 1909., 1908., 1907., 1906., 1905., 1904., 1903.,
# ...

# %%
data['Year'] = data['Year'].astype('int64')

# %%
data.Year.unique() #Columna Correcta
# Out:
# array([2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008,
#        2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997,
#        1996, 1995, 1984, 1994, 1993, 1992, 1991, 1990, 1989, 1969, 1988,
#        1987, 1986, 1985, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976,
#        1975, 1974, 1973, 1972, 1971, 1970, 1968, 1967, 1966, 1965, 1964,
#        1963, 1962, 1961, 1960, 1959, 1958, 1957, 1956, 1955, 1954, 1953,
#        1952, 1951, 1950, 1949, 1948, 1848, 1947, 1946, 1945, 1944, 1943,
#        1942, 1941, 1940, 1939, 1938, 1937, 1936, 1935, 1934, 1933, 1932,
#        1931, 1930, 1929, 1928, 1927, 1926, 1925, 1924, 1923, 1922, 1921,
#        1920, 1919, 1918, 1917, 1916, 1915, 1914, 1913, 1912, 1911, 1910,
#        1909, 1908, 1907, 1906, 1905, 1904, 1903, 1902, 1901, 1900, 1899,
#        1898, 1897, 1896, 1895, 1894, 1893, 1892, 1891, 1890, 1889, 1888,
#        1887, 1886, 1885, 1884, 1883, 1882, 1881, 1880, 1879, 1878, 1877,
# ...

# %%
data.Sex.value_counts()
# Out:
# M          5094
# F           637
# Unknown     565
# M             2
# N             2
# lli           1
# .             1
# Name: Sex, dtype: int64

# %%
data.Sex.replace(['M ', 'N', 'lli', '.'],
                           ['M', 'Unknown', 'Unknown', 'Unknown'],
                           inplace=True)

# %%
data.Sex.unique() #Columna Correcta
# Out:
# array(['F', 'M', 'Unknown'], dtype=object)

# %%
data.Type.unique() #Columna Correcta
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', 'Unknown', 'Boat', 'Boatomg'], dtype=object)

# %%
data.Pdf.unique() #Columna Correcta
# Out:
# array(['2018.06.25-Wolfe.pdf', '2018.06.18-McNeely.pdf',
#        '2018.06.09-Denges.pdf', ..., 'ND-0003-Ocracoke_1900-1905.pdf',
#        'ND-0002-JulesPatterson.pdf', 'ND-0001-Ceylon.pdf'], dtype=object)

# %%
data.Case_Number.unique()
# Out:
# array(['2018.06.25', '2018.06.18', '2018.06.09', ..., 'ND.0003',
#        'ND.0002', 'ND.0001'], dtype=object)

# %%
data.Activity.unique() #Columna Correcta
# Out:
# array(['Paddling', 'Standing', 'Surfing', ...,
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing', 'Wreck of  large double sailing canoe'],
#       dtype=object)

# %%
data.Activity = data.Activity.apply(fn.limpiar_act)

# %%
data.Activity.value_counts()
# Out:
# Swimming         1944
# Surfing          1424
# Fishing          1113
# Unknown           548
# Diving            487
# Sailing           308
# Walking           154
# Other             106
# Fighting           88
# Playing            74
# Flying             27
# Washing            17
# Filming             6
# Helping             4
# Photographing       2
# Name: Activity, dtype: int64

# %%
data.Species.unique() #Columna Correcta
# Out:
# array(['White shark', 'Unknown', '2 m shark', ..., "12' tiger shark",
#        'Blue pointers',
#        'Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable'],
#       dtype=object)

# %%
data.Species = data.Species.apply(fn.limpiar_spe)

# %%
data.Species.value_counts()
# Out:
# Unknown             3166
# Other               1388
# White Shark          667
# Tiger Shark          276
# Bull Shark           183
# Blacktip Shark        95
# Reef Shark            71
# Bronze Whale          64
# Mako Shark            61
# Nurse Shark           56
# Wobbegong Shark       49
# Blue Shark            49
# Hammerhead Shark      47
# Grey Nurse Shark      46
# Lemon Shark           34
# Spinner Shark         20
# Sand Shark            19
# Sandbar Shark          5
# Leopard Shark          2
# Silvertip Shark        2
# Tawney Shark           1
# Soupfin Shark          1
# Name: Species, dtype: int64

# %%
nan_cols = data.isna().sum() #columnas con valones nulos

nan_cols[nan_cols>0]
# Out:
# Series([], dtype: int64)

# %%
data.Type.unique() #Columna correcta
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', 'Unknown', 'Boat', 'Boatomg'], dtype=object)

# %%
data.Type.replace(['Boatomg'], ['Boating'], inplace = True)

# %%
data.Type.value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          204
# Boat             137
# Unknown            4
# Questionable       2
# Name: Type, dtype: int64

# %%
data.Name.value_counts().head() #Columna Correcta
# Out:
# Unknown           1536
# Andre Hartman        3
# M.C.                 3
# John Williams        3
# Greg Pickering       2
# Name: Name, dtype: int64

# %%
data.Name = data.Name.apply(fn.limpiar_nom)

# %%
data.Name.value_counts().head()
# Out:
# Unknown           1536
# Andre Hartman        3
# M.C.                 3
# John Williams        3
# Greg Pickering       2
# Name: Name, dtype: int64
